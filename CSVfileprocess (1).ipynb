# %%
import  pandas as pd

# %%
 

df=pd.read_csv("./details.csv")
print(df)
# Out:
#          name  age     course   fees  marks
# 0     praveen   25     python  25000     89
# 1       kiran   22       java  30000     76
# 2        siva   24      excel  15000     67
# 3       kumar   23     python  25000     92
# 4     sravani   21        sql  18000     81
# 5       divya   26  fullstack  45000     73
# 6      lokesh   27    powerbi  28000     88
# 7      nikhil   20       java  30000     69
# 8      anusha   22     python  25000     95
# 9       rahul   24      excel  15000     58
# 10    aravind   23        sql  18000     72
# 11    keerthi   25     python  25000     91
# 12     naveen   26  fullstack  45000     84
# 13       teja   22    powerbi  28000     66
# 14     harsha   24       java  30000     79
# 15      rekha   21      excel  15000     87
# 16    mounika   23     python  25000     93
# 17  chaitanya   27        sql  18000     70
# 18    sandhya   26  fullstack  45000     82
# 19      vamsi   25     python  25000     77
# 20     rakesh   23       java  30000     63
# 21      bindu   22    powerbi  28000     85
# 22   srikanth   24        sql  18000     90
# 23    alekhya   21      excel  15000     74
# 24   pranathi   26     python  25000     96
# 25      manoj   25  fullstack  45000     86
# 26      madhu   27       java  30000     68
# 27      kavya   23     python  25000     94
# 28     venkat   24    powerbi  28000     71
# 29    tejaswi   22        sql  18000     83
# 30     rajesh   25      excel  15000     62
# 31       anil   26     python  25000     97
# 32     varsha   21       java  30000     75
# 33      sneha   23        sql  18000     88
# 34      mohan   27    powerbi  28000     64
# 35     pavani   22      excel  15000     80
# 36      rohit   24  fullstack  45000     92
# 37      pooja   25     python  25000     90
# 38      surya   23       java  30000     78
# 39      priya   26      excel  15000     85

# %%
print(df.head())
# Out:
#       name  age  course   fees  marks
# 0  praveen   25  python  25000     89
# 1    kiran   22    java  30000     76
# 2     siva   24   excel  15000     67
# 3    kumar   23  python  25000     92
# 4  sravani   21     sql  18000     81

# %%
print(df.tail())
# Out:
#       name  age     course   fees  marks
# 35  pavani   22      excel  15000     80
# 36   rohit   24  fullstack  45000     92
# 37   pooja   25     python  25000     90
# 38   surya   23       java  30000     78
# 39   priya   26      excel  15000     85

# %%
print(df.shape)
# Out:
# (40, 5)

# %%
print(df.columns)
# Out:
# Index(['name', 'age', 'course', 'fees', 'marks'], dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    40 non-null     object
#  1   age     40 non-null     int64
#  2   course  40 non-null     object
#  3   fees    40 non-null     int64
#  4   marks   40 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 1.7+ KB
# None

# %%
print(df.describe())
# Out:
#              age          fees      marks
# count  40.000000     40.000000  40.000000
# mean   23.875000  25950.000000  80.250000
# std     1.950509   9026.882927  10.722012
# min    20.000000  15000.000000  58.000000
# 25%    22.000000  18000.000000  71.750000
# 50%    24.000000  25000.000000  81.500000
# 75%    25.250000  30000.000000  89.250000
# max    27.000000  45000.000000  97.000000

# %%
print(df["name"])
# Out:
# 0       praveen
# 1         kiran
# 2          siva
# 3         kumar
# 4       sravani
# 5         divya
# 6        lokesh
# 7        nikhil
# 8        anusha
# 9         rahul
# 10      aravind
# 11      keerthi
# 12       naveen
# 13         teja
# 14       harsha
# 15        rekha
# 16      mounika
# 17    chaitanya
# 18      sandhya
# 19        vamsi
# 20       rakesh
# 21        bindu
# 22     srikanth
# 23      alekhya
# 24     pranathi
# 25        manoj
# 26        madhu
# 27        kavya
# 28       venkat
# 29      tejaswi
# 30       rajesh
# 31         anil
# 32       varsha
# 33        sneha
# 34        mohan
# 35       pavani
# 36        rohit
# 37        pooja
# 38        surya
# 39        priya
# Name: name, dtype: object

# %%
print(df.loc[1])
# Out:
# name      kiran
# age          22
# course     java
# fees      30000
# marks        76
# Name: 1, dtype: object

# %%
print(df.iloc[2])
# Out:
# name       siva
# age          24
# course    excel
# fees      15000
# marks        67
# Name: 2, dtype: object

# %%
print(df.iloc[5])
# Out:
# name          divya
# age              26
# course    fullstack
# fees          45000
# marks            73
# Name: 5, dtype: object

# %%
age=df[df["age"]>=25]
print(age)
# Out:
#          name  age     course   fees  marks
# 0     praveen   25     python  25000     89
# 5       divya   26  fullstack  45000     73
# 6      lokesh   27    powerbi  28000     88
# 11    keerthi   25     python  25000     91
# 12     naveen   26  fullstack  45000     84
# 17  chaitanya   27        sql  18000     70
# 18    sandhya   26  fullstack  45000     82
# 19      vamsi   25     python  25000     77
# 24   pranathi   26     python  25000     96
# 25      manoj   25  fullstack  45000     86
# 26      madhu   27       java  30000     68
# 30     rajesh   25      excel  15000     62
# 31       anil   26     python  25000     97
# 34      mohan   27    powerbi  28000     64
# 37      pooja   25     python  25000     90
# 39      priya   26      excel  15000     85

# %%
answer=df[df["course"]=="java"]
print(answer)
# Out:
#       name  age course   fees  marks
# 1    kiran   22   java  30000     76
# 7   nikhil   20   java  30000     69
# 14  harsha   24   java  30000     79
# 20  rakesh   23   java  30000     63
# 26   madhu   27   java  30000     68
# 32  varsha   21   java  30000     75
# 38   surya   23   java  30000     78

# %%
print(df[["name","marks"]])
# Out:
#          name  marks
# 0     praveen     89
# 1       kiran     76
# 2        siva     67
# 3       kumar     92
# 4     sravani     81
# 5       divya     73
# 6      lokesh     88
# 7      nikhil     69
# 8      anusha     95
# 9       rahul     58
# 10    aravind     72
# 11    keerthi     91
# 12     naveen     84
# 13       teja     66
# 14     harsha     79
# 15      rekha     87
# 16    mounika     93
# 17  chaitanya     70
# 18    sandhya     82
# 19      vamsi     77
# 20     rakesh     63
# 21      bindu     85
# 22   srikanth     90
# 23    alekhya     74
# 24   pranathi     96
# 25      manoj     86
# 26      madhu     68
# 27      kavya     94
# 28     venkat     71
# 29    tejaswi     83
# 30     rajesh     62
# 31       anil     97
# 32     varsha     75
# 33      sneha     88
# 34      mohan     64
# 35     pavani     80
# 36      rohit     92
# 37      pooja     90
# 38      surya     78
# 39      priya     85

# %%
df["result"]=["pass" if m>=70 else "fail" for m in df["marks"]]
print(df)
# Out:
#          name  age     course   fees  marks result
# 0     praveen   25     python  25000     89   pass
# 1       kiran   22       java  30000     76   pass
# 2        siva   24      excel  15000     67   fail
# 3       kumar   23     python  25000     92   pass
# 4     sravani   21        sql  18000     81   pass
# 5       divya   26  fullstack  45000     73   pass
# 6      lokesh   27    powerbi  28000     88   pass
# 7      nikhil   20       java  30000     69   fail
# 8      anusha   22     python  25000     95   pass
# 9       rahul   24      excel  15000     58   fail
# 10    aravind   23        sql  18000     72   pass
# 11    keerthi   25     python  25000     91   pass
# 12     naveen   26  fullstack  45000     84   pass
# 13       teja   22    powerbi  28000     66   fail
# 14     harsha   24       java  30000     79   pass
# 15      rekha   21      excel  15000     87   pass
# 16    mounika   23     python  25000     93   pass
# 17  chaitanya   27        sql  18000     70   pass
# 18    sandhya   26  fullstack  45000     82   pass
# 19      vamsi   25     python  25000     77   pass
# 20     rakesh   23       java  30000     63   fail
# 21      bindu   22    powerbi  28000     85   pass
# 22   srikanth   24        sql  18000     90   pass
# 23    alekhya   21      excel  15000     74   pass
# 24   pranathi   26     python  25000     96   pass
# 25      manoj   25  fullstack  45000     86   pass
# 26      madhu   27       java  30000     68   fail
# 27      kavya   23     python  25000     94   pass
# 28     venkat   24    powerbi  28000     71   pass
# 29    tejaswi   22        sql  18000     83   pass
# 30     rajesh   25      excel  15000     62   fail
# 31       anil   26     python  25000     97   pass
# 32     varsha   21       java  30000     75   pass
# 33      sneha   23        sql  18000     88   pass
# 34      mohan   27    powerbi  28000     64   fail
# 35     pavani   22      excel  15000     80   pass
# 36      rohit   24  fullstack  45000     92   pass
# 37      pooja   25     python  25000     90   pass
# 38      surya   23       java  30000     78   pass
# 39      priya   26      excel  15000     85   pass

# %%
df.to_csv("output.csv", index="false")

# %%
df["marks"]=df["marks"]+5
print(df)
# Out:
#          name  age     course   fees  marks result
# 0     praveen   25     python  25000     94   pass
# 1       kiran   22       java  30000     81   pass
# 2        siva   24      excel  15000     72   fail
# 3       kumar   23     python  25000     97   pass
# 4     sravani   21        sql  18000     86   pass
# 5       divya   26  fullstack  45000     78   pass
# 6      lokesh   27    powerbi  28000     93   pass
# 7      nikhil   20       java  30000     74   fail
# 8      anusha   22     python  25000    100   pass
# 9       rahul   24      excel  15000     63   fail
# 10    aravind   23        sql  18000     77   pass
# 11    keerthi   25     python  25000     96   pass
# 12     naveen   26  fullstack  45000     89   pass
# 13       teja   22    powerbi  28000     71   fail
# 14     harsha   24       java  30000     84   pass
# 15      rekha   21      excel  15000     92   pass
# 16    mounika   23     python  25000     98   pass
# 17  chaitanya   27        sql  18000     75   pass
# 18    sandhya   26  fullstack  45000     87   pass
# 19      vamsi   25     python  25000     82   pass
# 20     rakesh   23       java  30000     68   fail
# 21      bindu   22    powerbi  28000     90   pass
# 22   srikanth   24        sql  18000     95   pass
# 23    alekhya   21      excel  15000     79   pass
# 24   pranathi   26     python  25000    101   pass
# 25      manoj   25  fullstack  45000     91   pass
# 26      madhu   27       java  30000     73   fail
# 27      kavya   23     python  25000     99   pass
# 28     venkat   24    powerbi  28000     76   pass
# 29    tejaswi   22        sql  18000     88   pass
# 30     rajesh   25      excel  15000     67   fail
# 31       anil   26     python  25000    102   pass
# 32     varsha   21       java  30000     80   pass
# 33      sneha   23        sql  18000     93   pass
# 34      mohan   27    powerbi  28000     69   fail
# 35     pavani   22      excel  15000     85   pass
# 36      rohit   24  fullstack  45000     97   pass
# 37      pooja   25     python  25000     95   pass
# 38      surya   23       java  30000     83   pass
# 39      priya   26      excel  15000     90   pass

# %%
df["marks"]=df["marks"]+5
print("file saved sucessfully!")
# Out:
# file saved sucessfully!

# %%
df=pd.read_csv("./output.csv") 
print(df)
# Out:
#     Unnamed: 0       name  age     course   fees  marks result
# 0            0    praveen   25     python  25000     89   pass
# 1            1      kiran   22       java  30000     76   pass
# 2            2       siva   24      excel  15000     67   fail
# 3            3      kumar   23     python  25000     92   pass
# 4            4    sravani   21        sql  18000     81   pass
# 5            5      divya   26  fullstack  45000     73   pass
# 6            6     lokesh   27    powerbi  28000     88   pass
# 7            7     nikhil   20       java  30000     69   fail
# 8            8     anusha   22     python  25000     95   pass
# 9            9      rahul   24      excel  15000     58   fail
# 10          10    aravind   23        sql  18000     72   pass
# 11          11    keerthi   25     python  25000     91   pass
# 12          12     naveen   26  fullstack  45000     84   pass
# 13          13       teja   22    powerbi  28000     66   fail
# 14          14     harsha   24       java  30000     79   pass
# 15          15      rekha   21      excel  15000     87   pass
# 16          16    mounika   23     python  25000     93   pass
# 17          17  chaitanya   27        sql  18000     70   pass
# 18          18    sandhya   26  fullstack  45000     82   pass
# 19          19      vamsi   25     python  25000     77   pass
# 20          20     rakesh   23       java  30000     63   fail
# 21          21      bindu   22    powerbi  28000     85   pass
# 22          22   srikanth   24        sql  18000     90   pass
# 23          23    alekhya   21      excel  15000     74   pass
# 24          24   pranathi   26     python  25000     96   pass
# 25          25      manoj   25  fullstack  45000     86   pass
# 26          26      madhu   27       java  30000     68   fail
# 27          27      kavya   23     python  25000     94   pass
# 28          28     venkat   24    powerbi  28000     71   pass
# 29          29    tejaswi   22        sql  18000     83   pass
# 30          30     rajesh   25      excel  15000     62   fail
# 31          31       anil   26     python  25000     97   pass
# 32          32     varsha   21       java  30000     75   pass
# 33          33      sneha   23        sql  18000     88   pass
# 34          34      mohan   27    powerbi  28000     64   fail
# 35          35     pavani   22      excel  15000     80   pass
# 36          36      rohit   24  fullstack  45000     92   pass
# 37          37      pooja   25     python  25000     90   pass
# 38          38      surya   23       java  30000     78   pass
# 39          39      priya   26      excel  15000     85   pass

# %%
df.fillna("N/A", inplace=True)
print(df)
# Out:
#     Unnamed: 0       name  age     course   fees  marks result
# 0            0    praveen   25     python  25000     89   pass
# 1            1      kiran   22       java  30000     76   pass
# 2            2       siva   24      excel  15000     67   fail
# 3            3      kumar   23     python  25000     92   pass
# 4            4    sravani   21        sql  18000     81   pass
# 5            5      divya   26  fullstack  45000     73   pass
# 6            6     lokesh   27    powerbi  28000     88   pass
# 7            7     nikhil   20       java  30000     69   fail
# 8            8     anusha   22     python  25000     95   pass
# 9            9      rahul   24      excel  15000     58   fail
# 10          10    aravind   23        sql  18000     72   pass
# 11          11    keerthi   25     python  25000     91   pass
# 12          12     naveen   26  fullstack  45000     84   pass
# 13          13       teja   22    powerbi  28000     66   fail
# 14          14     harsha   24       java  30000     79   pass
# 15          15      rekha   21      excel  15000     87   pass
# 16          16    mounika   23     python  25000     93   pass
# 17          17  chaitanya   27        sql  18000     70   pass
# 18          18    sandhya   26  fullstack  45000     82   pass
# 19          19      vamsi   25     python  25000     77   pass
# 20          20     rakesh   23       java  30000     63   fail
# 21          21      bindu   22    powerbi  28000     85   pass
# 22          22   srikanth   24        sql  18000     90   pass
# 23          23    alekhya   21      excel  15000     74   pass
# 24          24   pranathi   26     python  25000     96   pass
# 25          25      manoj   25  fullstack  45000     86   pass
# 26          26      madhu   27       java  30000     68   fail
# 27          27      kavya   23     python  25000     94   pass
# 28          28     venkat   24    powerbi  28000     71   pass
# 29          29    tejaswi   22        sql  18000     83   pass
# 30          30     rajesh   25      excel  15000     62   fail
# 31          31       anil   26     python  25000     97   pass
# 32          32     varsha   21       java  30000     75   pass
# 33          33      sneha   23        sql  18000     88   pass
# 34          34      mohan   27    powerbi  28000     64   fail
# 35          35     pavani   22      excel  15000     80   pass
# 36          36      rohit   24  fullstack  45000     92   pass
# 37          37      pooja   25     python  25000     90   pass
# 38          38      surya   23       java  30000     78   pass
# 39          39      priya   26      excel  15000     85   pass

# %%
import pandas as pd
data={
    'ID':[1,2,3,4,5],
    'Name':["praveen", "vishnu", "nivas", "Ram", "Kavi"]
}

df=pd.DataFrame(data)

print(df)
# Out:
#    ID     Name
# 0   1  praveen
# 1   2   vishnu
# 2   3    nivas
# 3   4      Ram
# 4   5     Kavi

# %%
df.to_csv("output.csv",index="false")

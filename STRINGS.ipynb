# %%
print("Praveenkumar Thirumalai")

# %%
print("""
     praveenkumar
     MBA GRADUDATION
""")
# Out:
#      praveenkumar
#      MBA GRADUDATION

# %%
print("""
     praveenkumar
     MBA GRADUDATION "M KUMARASAMY COLLEGE OF ENGENEERING KARUR"
""")
# Out:
#      praveenkumar
#      MBA GRADUDATION "M KUMARASAMY COLLEGE OF ENGENEERING KARUR"

# %%
print("praveenkumar thirumalai 'madurao'")
# Out:
# praveenkumar thirumalai 'madurao'

# %%
print('praveenkumar thirumalai "madurao"')
# Out:
# praveenkumar thirumalai "madurao"

# %%
name=("praveenkumar thirumalai")

print(name)
print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[4])
# Out:
# praveenkumar thirumalai
# p
# r
# a
# v
# e

# %%
name="praveenkumar thirumalai"
for i in name:
    print(i)
# Out:
# p
# r
# a
# v
# e
# e
# n
# k
# u
# m
# a
# r
#
# t
# h
# i
# r
# u
# m
# a
# l
# a
# i

# %%
name="praveenkumar thirumalai"
print(len(name))
# Out:
# 23

# %%
conetent="Happy diwali 2025, enjoy your holidays"
print("diwali" in conetent)
print("pongal" not in conetent)
# Out:
# True
# True

# %%
festivals=("diwali", "cristmas", "newyear","pongal")
if "diwali" in festivals:
  print("yes")
else:
  print("no")
# Out:
# yes

# %%
festivals=("diwali", "cristmas", "newyear","pongal")
print(festivals[1:3])
# Out:
# ('cristmas', 'newyear')

# %%
name="praveenkumar thirumalai"
print(name[0:10])
print(name[:10])
print(name[5:])
# Out:
# praveenkum
# praveenkum
# enkumar thirumalai

# %%
name="praveenkumar thirumalai"
print(name.upper())
# Out:
# PRAVEENKUMAR THIRUMALAI

# %%
name="PRAVEENKUMAR THIRUMALAI"
print(name.lower())
# Out:
# praveenkumar thirumalai

# %%
name="                  praveenkumar thirumalai"
print(name)
print(name.strip())
# Out:
#                   praveenkumar thirumalai
# praveenkumar thirumalai

# %%
MSG="Call Cat"
print(MSG.replace("C", "B"))
# Out:
# Ball Bat

# %%
course="BBA MBA CA MCA MA ME"
answer=course.split(" ")
print(answer)
print(course)

print(type(answer))
print(type(course))

print(len(answer))
print(len(course))
# Out:
# ['BBA', 'MBA', 'CA', 'MCA', 'MA', 'ME']
# BBA MBA CA MCA MA ME
# <class 'list'>
# <class 'str'>
# 6
# 20

# %%
name="praveenkumar thirumalai"
answer=name.capitalize()
print(answer)
# Out:
# Praveenkumar thirumalai

# %%
name="Praveenkumar Thirumalai"
answer=name.casefold()
print(answer)
# Out:
# praveenkumar thirumalai

# %%
content="Praveenkumar Thirumalai"

anwer=content.center(25, "*")
print(answer)
# Out:
# praveenkumar thirumalai

# %%
txt="I love nature, nature is beautiful"
answer=txt.count("nature")
print(answer)
# Out:
# 2

# %%
txt="I love nature, nature is beautiful, natures saves responsibility is ours"
answer=txt.endswith("responsibility is ours")
print(answer)

answer=txt.startswith("I love artificial")
print(answer)
# Out:
# True
# False

# %%
txt="I love nature, nature is beautiful, natures saves responsibility is ours"
answer=txt.find("nature")
print(answer)

answer=txt.index("nature")
print(answer)
# Out:
# 7
# 7

# %%
txt="praveenkumar123"
answer=txt.isalnum()
print(answer)
# Out:
# True

# %%
txt="praveenkumar"
answer=txt.isalpha()
print(answer)
# Out:
# True

# %%
txt="praveenkumar"
answer=txt.islower()
print(answer)
# Out:
# True

# %%
txt="PRAVEENKUMAR"
answer=txt.isupper()
print(answer)
# Out:
# True

# %%
course=("BBA MBA CA MCA MA ME")
check=" ".join(course)
print(check)

print(type(course))
print(type(course))
# Out:
# B B A   M B A   C A   M C A   M A   M E
# <class 'str'>
# <class 'str'>

# %%
S1="Excel"
S2="Python"
answer=S1+ " " +S2
print(answer)
# Out:
# Excel Python

# %%
marks=45
txt=f"praveen - python mark {marks}"
print(txt)
# Out:
# praveen - python mark 45

# %%
txt="123"
answer=txt.isnumeric()
print(answer)
# Out:
# True

# %%
check=("sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "sauturday")
answer=check.count("sunday")
print(answer)
# Out:
# 1

# %%
check=("sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "saturday")
answer=check.count("january")
print(answer)

answer=check.index("saturday")
print(answer)
# Out:
# 0
# 6

# %%
check=("sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "sauturday")
print(check)
print(type(check))
print(len(check))
# Out:
# ('sunday', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'sauturday')
# <class 'tuple'>
# 7

# %%
check=(("sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "sauturday"))
print(check)
print(type(check))
# Out:
# ('sunday', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'sauturday')
# <class 'tuple'>

# %%
chec=("sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "sauturday")
print(chec[0])
print(chec[1])
print(chec[2])
print(chec[3])
print(chec[4])
print(chec[5])
print(chec[6])
print(type)
# Out:
# sunday
# monday
# tuesday
# wednessday
# thursday
# friday
# sauturday
# <class 'type'>

# %%
chec=("sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "sauturday")

print(chec[-1])
print(chec[-2])
print(chec[-3])
print(chec[-4])
print(chec[-5])
print(chec[-6])
print(check[-7])
# Out:
# sauturday
# friday
# thursday
# wednessday
# tuesday
# monday
# sunday

# %%
chec=("sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "sauturday")
print(check[2:5])
# Out:
# ('tuesday', 'wednessday', 'thursday')

# %%
print(check[2:])
# Out:
# ('tuesday', 'wednessday', 'thursday', 'friday', 'sauturday')

# %%
print(check[:4])
# Out:
# ('sunday', 'monday', 'tuesday', 'wednessday')

# %%
check=("sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "sauturday")
if "january" in check:
  print("yes")
else:
  print("No")
# Out:
# No

# %%
tuplevalue=("sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "sauturday")
print(tuplevalue)

listvalue=list(tuplevalue)
listvalue[0]="sunday is holy day"

tuplevalue=tuple(listvalue)
print(tuplevalue)
# Out:
# ('sunday', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'sauturday')
# ('sunday is holy day', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'sauturday')

# %%
tuplevalue=("chennai", "bengaluru", "delhi", "mumbai")
print(tuplevalue)

listvalue=list(tuplevalue)
listvalue.append("hyderabad")

tuplevalue=tuple(listvalue)
print(tuplevalue)
# Out:
# ('chennai', 'bengaluru', 'delhi', 'mumbai')
# ('chennai', 'bengaluru', 'delhi', 'mumbai', 'hyderabad')

# %%
tuplevalue=("chennai", "bengaluru", "delhi", "mumbai")
print(tuplevalue)
setvalue=set(tuplevalue)
setvalue.add("hydearbad")

tuplevalue=tuple(setvalue)
print(tuplevalue)
# Out:
# ('chennai', 'bengaluru', 'delhi', 'mumbai')
# ('chennai', 'delhi', 'mumbai', 'hydearbad', 'bengaluru')

# %%
tuplevalue1=("monday", "tuesday", "wednessday", "thursday", "friday")
tuplevalue2=("saturday", "sunday")


tuplevalue1+=tuplevalue2



print(tuplevalue1)
# Out:
# ('monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'saturday', 'sunday')

# %%
tuplevalue=("sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "sauturday")

listvalue=list(tuplevalue)
listvalue.remove("sunday")

tuplevalue=tuple(listvalue)
print(tuplevalue)
# Out:
# ('monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'sauturday')

# %%
tuplevalue=("chennai", "bengaluru", "delhi", "mumbai")
#(c1, c2, c3, c4)=tuplevalue
c1, *c2=tuplevalue

print(c1)
print(c2)
# Out:
# chennai
# ['bengaluru', 'delhi', 'mumbai']

# %%
tuplevalue=("chennai", "bengaluru", "delhi", "mumbai")
for i in tuplevalue:
  print(i)
# Out:
# chennai
# bengaluru
# delhi
# mumbai

# %%
i=0
while i<len(tuplevalue):
  print(tuplevalue[i])
  i=i+1
# Out:
# chennai
# bengaluru
# delhi
# mumbai

# %%
tuplevalue=("sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "sauturday")
for i in tuplevalue:
 print(i)
# Out:
# sunday
# monday
# tuesday
# wednessday
# thursday
# friday
# sauturday

# %%
i=0
while i<len(tuplevalue):
  print(tuplevalue[i])
  i=i+1
# Out:
# sunday
# monday
# tuesday
# wednessday
# thursday
# friday
# sauturday

# %%
tuplevalue1=("monday", "tuesday", "wednessday", "thursday", "friday")
tuplevalue2=("saturday", "sunday")

answer=tuplevalue1+tuplevalue2

print(answer)
# Out:
# ('monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'saturday', 'sunday')

# %%
tuplevalue=("sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "sauturday")
answer=tuplevalue1*3
print(answer)
# Out:
# ('monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday')

# %%
for i in range(len(tuplevalue)):
  print(tuplevalue[i])
# Out:
# sunday
# monday
# tuesday
# wednessday
# thursday
# friday
# sauturday

# %%
#Exception handling
try:
   a=12/2
   print(a)
except ZeroDivisionError:
   print("Error: Division by zero is not allowed....")
finally:
   print("thank you")
# Out:
# 6.0
# thank you

# %%
try:
   a=12/0
   print(a)
except ZeroDivisionError:
   print("Error: Division by zero is not allowed....")
finally:
   print("thank you")
# Out:
# Error: Division by zero is not allowed....
# thank you

# %%
try:
   a=15/5
   print(a)
except ZeroDivisionError:
  print("Error: Division by zero is not allowed....")
finally:
  print("thankyou")
# Out:
# 3.0
# thankyou

# %%
try:
  num=int(input("Enter a number: "))
  print(10/num)
except ZeroDivisionError:
  print("you cannot divided by zero")
except ValueError:
  print("invallid input: please enter the value")
# Out:
# Enter a number: 0
# you cannot divided by zero

# %%
try:
  num=int(input("Enter the number"))
  print(12/num)
except ZeroDivisionError:
    print("you can not divided by zero")
except ValueError:
  print("Invalide input: please enter the value")
# Out:
# Enter the numbertwel
# Invalide input: please enter the value

# %%
try:
  num=int(input("Enter the number"))
  print(12/num)
except ZeroDivisionError:
    print("you can not divided by zero")
except ValueError:
  print("Invalide input: please enter the value")
# Out:
# Enter the number0
# you can not divided by zero

# %%
try:
  num1=int(input("Enter the number 1 : "))
  num2=int(input("Enter the number 2 : "))
  answer=num1/num2
  print("answer")
except (ZeroDivisionError, ValueError):
  print("invalid input or divided by zero")
# Out:
# Enter the number 1 : 20
# Enter the number 2 : 2
# answer

# %%
try:
  num1=int(input("Enter the number 1 : "))
  num2=int(input("Enter the number 2 : "))
  answer=num1/num2
  print("answer")
except (ZeroDivisionError, ValueError):
  print("invalid input or divided by zero")
# Out:
# Enter the number 1 : 20
# Enter the number 2 : 0
# invalid input or divided by zero

# %%
age=int(input("Enter you age : "))
if age<18:
  raise ValueError("age must be 18 or above")
else:
  print("you are eligible")
# Out:
# Enter you age : 56
# you are eligible

# %%
age=int(input("enter your age : "))
if age<21:
  raise ValueError("age must be 21 or above")
else:
  print("you are eligible")
# Out:
# enter your age : 11
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2612052531.py in <cell line: 0>()
#       1 age=int(input("enter your age : "))
#       2 if age<21:
# ----> 3   raise ValueError("age must be 21 or above")
#       4 else:
#       5   print("you are eligible")
#
# ValueError: age must be 21 or above

# %%
try:
  print(7+"67")
except TypeError:
  print("you cannot add number and error")
# Out:
# you cannot add number and error

# %%
try:
  listvalue=["java", "python", "excel", "sql"]
  print(listvalue[9])
except IndexError:
  print("index out of range")
# Out:
# index out of range

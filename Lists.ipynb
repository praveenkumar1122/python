# %%
#List-Lists or used to store multiple items in a single value
check=["sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "saturday"]
print(check)
print(type(check))
print (len(check))
# Out:
# ['sunday', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'saturday']
# <class 'list'>
# 7

# %%
check=["sunday",1200, True,"monday",5000, "tuesday", 6000, "wednessday", False, "thursday", "friday", "saturday"]
print(check)
# Out:
# ['sunday', 1200, True, 'monday', 5000, 'tuesday', 6000, 'wednessday', False, 'thursday', 'friday', 'saturday']

# %%
#list () constructor
check=list(("sunday",1200, True,"monday",5000, "tuesday", 6000, "wednessday", False, "thursday", "friday", "saturday"))
print(check)
print(type(check))
# Out:
# ['sunday', 1200, True, 'monday', 5000, 'tuesday', 6000, 'wednessday', False, 'thursday', 'friday', 'saturday']
# <class 'list'>

# %%
check=["sunday",1200, True,"monday",5000, "tuesday", 6000, "wednessday", False, "thursday", "friday", "saturday"]
print(len(check))
print(check[0])
print(check[1])
print(check[2])
print(check[3])
print(check[4])

print(check[-1])
print(check[-2])
print(check[-3])
print(check[-4])
print(check[-5])
print(check[-6])
# Out:
# 12
# sunday
# 1200
# True
# monday
# 5000
# saturday
# friday
# thursday
# False
# wednessday
# 6000

# %%
check=["sunday",1200, True,"monday",5000, "tuesday", 6000, "wednessday", False, "thursday", "friday", "saturday"]
print(check[2:5])
# Out:
# [True, 'monday', 5000]

# %%
check=["sunday",1200, True,"monday",5000, "tuesday", 6000, "wednessday", False, "thursday", "friday", "saturday"]

print(check)


if 6000 in check:
  print("yes")
else:
  print("no")
# Out:
# ['sunday', 1200, True, 'monday', 5000, 'tuesday', 6000, 'wednessday', False, 'thursday', 'friday', 'saturday']
# yes

# %%
check=["sunday",1200, True,"monday",5000, "tuesday", 6000, "wednessday", False, "thursday", "friday", "saturday"]

print(check)

answer=input("search data")
if answer in check:
  print("yes")
else:
  print("no")
# Out:
# ['sunday', 1200, True, 'monday', 5000, 'tuesday', 6000, 'wednessday', False, 'thursday', 'friday', 'saturday']
# search data1200
# no

# %%
check=["sunday",1200, True,"monday",5000, "tuesday", 6000, "wednessday", False, "thursday", "friday", "saturday"]
print(check)
print(check[2])
check[2]="TPK & PK & THIRUMALAI"
print(check)
print(check[2])
# Out:
# ['sunday', 1200, True, 'monday', 5000, 'tuesday', 6000, 'wednessday', False, 'thursday', 'friday', 'saturday']
# True
# ['sunday', 1200, 'TPK & PK & THIRUMALAI', 'monday', 5000, 'tuesday', 6000, 'wednessday', False, 'thursday', 'friday', 'saturday']
# TPK & PK & THIRUMALAI

# %%
check=["sunday",1200, True,"monday",5000, "tuesday", 6000, "wednessday", False, "thursday", "friday", "saturday"]

print(check)
check[1:3]=["january", "february"]
print(check)
# Out:
# ['sunday', 1200, True, 'monday', 5000, 'tuesday', 6000, 'wednessday', False, 'thursday', 'friday', 'saturday']
# ['sunday', 'january', 'february', 'monday', 5000, 'tuesday', 6000, 'wednessday', False, 'thursday', 'friday', 'saturday']

# %%
print(check[:5])
# Out:
# ['sunday', 'january', 'february', 'monday', 5000]

# %%
print(check[5:])
# Out:
# ['tuesday', 6000, 'wednessday', False, 'thursday', 'friday', 'saturday']

# %%
check=["sunday",1200, True,"monday",5000, "tuesday", 6000, "wednessday", False, "thursday", "friday", "saturday"]
check.insert(1, "december")
print(check)
# Out:
# ['sunday', 'december', 1200, True, 'monday', 5000, 'tuesday', 6000, 'wednessday', False, 'thursday', 'friday', 'saturday']

# %%
check=["sunday",1200, True,"monday",5000, "tuesday", 6000, "wednessday", False, "thursday", "friday", "saturday"]
check.append("december")
print(check)
# Out:
# ['sunday', 1200, True, 'monday', 5000, 'tuesday', 6000, 'wednessday', False, 'thursday', 'friday', 'saturday', 'december']

# %%
A1=["sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "saturday"]
A2=[90,90,80,70,60,50,78]
print(A1)
A1.extend(A2)
print(A1)
# Out:
# ['sunday', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'saturday']
# ['sunday', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'saturday', 90, 90, 80, 70, 60, 50, 78]

# %%
A1=["sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "saturday"]
print(A1)
A1.remove("sunday")
print(A1)
# Out:
# ['sunday', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'saturday']
# ['monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'saturday']

# %%
A1=["sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "saturday"]
print(A1)
print(A1.pop(2))
print(A1)
# Out:
# ['sunday', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'saturday']
# tuesday
# ['sunday', 'monday', 'wednessday', 'thursday', 'friday', 'saturday']

# %%
A1=["sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "saturday"]
print(A1)
print(A1.pop())
print(A1)
# Out:
# ['sunday', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'saturday']
# saturday
# ['sunday', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday']

# %%
A1=["sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "saturday"]
print(A1)
del A1[0]
print(A1)
# Out:
# ['sunday', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'saturday']
# ['monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'saturday']

# %%
A1=["sunday", "monday", "tuesday", "wednessday", "thursday", "friday", "saturday"]
print(A1)
A1.clear()
print(A1)
# Out:
# ['sunday', 'monday', 'tuesday', 'wednessday', 'thursday', 'friday', 'saturday']
# []

# %%
##DAY 4
Mark=int(input("Enter the Mark"))

if Mark>=35:
 print("pass")

if Mark<35:
  print("faill")
# Out:
# Enter the Mark85
# pass

# %%
Mark=int(input("Enter the Mark"))

if Mark>=20:
  print("good")

if Mark<20:
  print("average")
# Out:
# Enter the Mark52
# good

# %%
kilograme=int(input("Enter the kilograme"))
if kilograme>=52:
  print("full")
else:
  print("notfull")
# Out:
# Enter the kilograme62
# full

# %%
num=int(input("enter the number: "))
if(num%2==0):
 print(num, " _, even number")
 else:
  print(num, " -, odd number")
# Out:
# enter the number: 15
# 15  -, odd number

# %%
year=int(input("enter the year"))
if(year%4==0):
  print(year,"-, leap year")

else:
  print(year,"-, not leap year")
# Out:
# enter the year1999
# 1999 -, not leap year

# %%
a=int(input("enter the A value"))
b=int(input("enter the B value"))

if(a>b):
 print("A is biggest value")
else:
 print("B is biggest value")
# Out:
# enter the A value16
# enter the B value25
# B is biggest value

# %%
letter=input("entter the letter")

if(letter=="A" or letter=="E" or letter=="I" or letter=="O" or letter=="U" or letter=="a" or letter=="e" or letter=="i" or letter=="o" or letter=="u"):
 print("VL")
else:
 print("NVL")
# Out:
# entter the lettera
# VL

# %%
NUM=int(input("enter the number"))
if(NUM>0):
 print("+ve")
if(NUM<0):
  print("+VE")
else:
  print("ZERO")
# Out:
# enter the number0
# ZERO

# %%
a=int(input("enter the a value"))
b=int(input("enter the b value"))
c=int(input("enter the c value"))

if(a>b and a>c):
  print("a is the big valaue")
elif(b>a and b>c):
  print("b is the big valaue")
elif(c>a and c>b):
  print("c is the big valaue")
else:
  print("a,b,c - same value")
# Out:
# enter the a value12
# enter the b value15
# enter the c value16
# c is the big valaue
